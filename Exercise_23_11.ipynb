# %%
list1 = []
n = int(input("Enter the size of the list : "))
for i in range(n) :
    list1.append(int(input("Enter a number : ")))
largest = secondLargest = 0
for i in list1 :
    if i > largest:
        secondLargest = largest
        largest = i
    elif i > secondLargest and i < largest:
        secondLargest = i
        
print("List is : ",list1)
print("Second largest element of the list is : ",secondLargest)
# Out:
# Enter the size of the list : 5
# Enter a number : 0
# Enter a number : 1
# Enter a number : 0
# Enter a number : 1
# Enter a number : 1
# List is :  [0, 1, 0, 1, 1]
# Second largest element of the list is :  1

# %%
n = int(input("Enter the value of n : "))
sumOfSeries = 1

for i in range(1,n+1) :
    fact = 1
    for j in range(1, i+1) :
            fact *= j
    sumOfSeries += 1 / fact
print("Sum of series is : {:.2f}".format(sumOfSeries))
# Out:
# Enter the value of n : 4
# Sum of series is : 2.71

# %%
def addition(num1, num2) :
    return num1 + num2
def substraction(num1, num2) :
    return num1 - num2
def multiplication(num1, num2) :
    return num1 * num2
def division(num1, num2) :
    return num1 / num2

while(1) :
    print("1. Addition\n2. Substraction\n3. Multiplication\n4. Division\n5. Exit")
    choice = int(input("Enter your choice : "))
    
    if choice == 1:
        n1 = float(input("Enter the first number : "))
        n2 = float(input("Enter the second number : "))
        print("The sum of given two numbers is : ",addition(n1,n2))
    elif choice == 2:
        n1 = float(input("Enter the first number : "))
        n2 = float(input("Enter the second number : "))
        print("The difference of given two numbers is : ",substraction(n1,n2))
    elif choice == 3:
        n1 = float(input("Enter the first number : "))
        n2 = float(input("Enter the second number : "))
        print("The product of given two numbers is : ",multiplication(n1,n2))
    elif choice == 4:
        n1 = float(input("Enter the first number : "))
        n2 = float(input("Enter the second number : "))
        print("The quotient of given two numbers is : ",division(n1,n2))
    elif choice == 5:
        break
    else :
        print("Invalid choice. Please enter valid option")
# Out:
# 1. Addition
# 2. Substraction
# 3. Multiplication
# 4. Division
# 5. Exit
# Enter your choice : 1
# Enter the first number : 3.5
# Enter the second number : 6.1
# The sum of given two numbers is :  9.6
# 1. Addition
# 2. Substraction
# 3. Multiplication
# 4. Division
# 5. Exit
# Enter your choice : 2
# Enter the first number : 3
# Enter the second number : 7
# The difference of given two numbers is :  -4.0
# 1. Addition
# 2. Substraction
# 3. Multiplication
# 4. Division
# 5. Exit
# Enter your choice : 3
# Enter the first number : 7
# Enter the second number : 8
# The product of given two numbers is :  56.0
# 1. Addition
# 2. Substraction
# 3. Multiplication
# 4. Division
# 5. Exit
# Enter your choice : 4
# Enter the first number : 1
# Enter the second number : 2
# The quotient of given two numbers is :  0.5
# 1. Addition
# 2. Substraction
# 3. Multiplication
# 4. Division
# 5. Exit
# Enter your choice : 5

# %%
def addition(list1) :
    sum1 = 0
    for i in list1:
        sum1 += i
    return sum1
def substraction(list1) :
    diff = list1[0]
    for i in range(1, len(list1)):
        diff -= list1[i]
    return diff
def multiplication(list1) :
    mul = 1
    for i in list1:
        mul *= i
    return mul
def division(list1) :
    div = list1[0]
    for i in range(1, len(list1)):
        div /= list1[i]
    return div

while(1) :
    print("1. Addition\n2. Substraction\n3. Multiplication\n4. Division\n5. Exit")
    choice = int(input("Enter your choice : "))
    
    if choice == 1:
        numList = []
        n = int(input("Enter how many numbers you want to add ? "))
        for i in range(n) :
            numList.append(float(input("Enter a number : ")))
                      
        print("The sum of given two numbers is : ",addition(numList))
    elif choice == 2:
        numList = []
        n = int(input("Enter how many numbers you want to substract ? "))
        for i in range(n) :
            numList.append(float(input("Enter a number : ")))
        print("The difference of given two numbers is : ",substraction(numList))
    elif choice == 3:
        numList = []
        n = int(input("Enter how many numbers you want to multiply ? "))
        for i in range(n) :
            numList.append(float(input("Enter a number : ")))
        print("The product of given two numbers is : ",multiplication(numList))
    elif choice == 4:
        numList = []
        n = int(input("Enter how many numbers you want to divide ? "))
        for i in range(n) :
            numList.append(float(input("Enter a number : ")))
        print("The quotient of given two numbers is : ",division(numList))
    elif choice == 5:
        break
    else :
        print("Invalid choice. Please enter valid option")
# Out:
# 1. Addition
# 2. Substraction
# 3. Multiplication
# 4. Division
# 5. Exit
# Enter your choice : 2
# Enter how many numbers you want to substract ? 4
# Enter a number : 6
# Enter a number : 5
# Enter a number : 1
# Enter a number : 3
# The difference of given two numbers is :  -3.0
# 1. Addition
# 2. Substraction
# 3. Multiplication
# 4. Division
# 5. Exit
# Enter your choice : 3
# Enter how many numbers you want to multiply ? 4
# Enter a number : 2
# Enter a number : 3
# Enter a number : 5
# Enter a number : 3
# The product of given two numbers is :  90.0
# 1. Addition
# 2. Substraction
# 3. Multiplication
# 4. Division
# 5. Exit
# Enter your choice : 4
# Enter how many numbers you want to divide ? 4
# Enter a number : 5
# Enter a number : 2.5
# Enter a number : 2
# Enter a number : 4
# The quotient of given two numbers is :  0.25
# 1. Addition
# 2. Substraction
# 3. Multiplication
# 4. Division
# 5. Exit
# Enter your choice : 5
